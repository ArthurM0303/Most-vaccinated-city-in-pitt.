# %%
import pandas as pd

covid = pd.read_csv("covid_vax_municipal.csv")
covid. head()
# Out:
#   neighborhood_municipality  total_partially_vaccinated  \
# 0                 Aspinwall                         264
# 1                    Avalon                         345
# 2           Baldwin Borough                        1421
# 3          Baldwin Township                         126
# 4                  Ben Avon                         173
#
#    total_fully_vaccinated  total_fully_vaccinated_w_booster
# 0                    1136                              1175
# 1                    1703                              1445
# 2                    7370                              7325
# 3                     678                               746
# 4                     680                               656

# %%
covid.sort_values(["total_fully_vaccinated_w_booster","total_fully_vaccinated","total_partially_vaccinated"], ascending = False)
# Out:
#           neighborhood_municipality  total_partially_vaccinated  \
# 39                    Mount Lebanon                        3463
# 6                       Bethel Park                        2328
# 95                             Ross                        2444
# 45                       Penn Hills                        2818
# 144                      McCandless                        2443
# ..                              ...                         ...
# 30                        Haysville                           5
# 49   Arlington Heights (Pittsburgh)                          18
# 166            Chateau (Pittsburgh)                           8
# 215                        Trafford                           0
# 145                        Mcdonald                           2
#
#      total_fully_vaccinated  total_fully_vaccinated_w_booster
# 39                    12008                             14594
# 6                     11223                             13100
# ...

# %% [markdown]
# By reading the table above, we can see that the city "Mount Lebanon" is the best city in Pittsburgh, because it has the most number of vaccinated people in pittsburgh, this city is the safest city in pitt.
